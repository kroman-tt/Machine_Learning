# %% [markdown]
# ### Understanding linear regretion

# %%
# !pip install scikit-learn

# %% [markdown]
# ### importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### writing random seed to maintain reproducibility

# %%
np.random.seed(42)

# %% [markdown]
# Generate the synthetic data for 100 students

# %%
n_students = 100  
study_hours = np.random.uniform(0,10, n_students)

# %%
study_hours
# Out:
# array([3.74540119, 9.50714306, 7.31993942, 5.98658484, 1.5601864 ,
#        1.5599452 , 0.58083612, 8.66176146, 6.01115012, 7.08072578,
#        0.20584494, 9.69909852, 8.32442641, 2.12339111, 1.81824967,
#        1.8340451 , 3.04242243, 5.24756432, 4.31945019, 2.9122914 ,
#        6.11852895, 1.39493861, 2.92144649, 3.66361843, 4.56069984,
#        7.85175961, 1.99673782, 5.14234438, 5.92414569, 0.46450413,
#        6.07544852, 1.70524124, 0.65051593, 9.48885537, 9.65632033,
#        8.08397348, 3.04613769, 0.97672114, 6.84233027, 4.40152494,
#        1.22038235, 4.9517691 , 0.34388521, 9.09320402, 2.58779982,
#        6.62522284, 3.11711076, 5.20068021, 5.46710279, 1.84854456,
#        9.69584628, 7.75132823, 9.39498942, 8.9482735 , 5.97899979,
#        9.21874235, 0.88492502, 1.95982862, 0.45227289, 3.25330331,
#        3.8867729 , 2.71349032, 8.28737509, 3.56753327, 2.8093451 ,
#        5.42696083, 1.40924225, 8.02196981, 0.74550644, 9.86886937,
#        7.72244769, 1.98715682, 0.05522117, 8.15461428, 7.06857344,
#        7.29007168, 7.71270347, 0.74044652, 3.58465729, 1.1586906 ,
#        8.63103426, 6.23298127, 3.30898025, 0.6355835 , 3.10982322,
#        3.25183322, 7.29606178, 6.37557471, 8.87212743, 4.72214925,
#        1.19594246, 7.13244787, 7.60785049, 5.61277198, 7.7096718 ,
#        4.93795596, 5.22732829, 4.27541018, 0.25419127, 1.07891427])

# %% [markdown]
# calculate the marks by defining the slope,intercept and noise

# %%
noise_factor = np.random.normal(0, 5, n_students)

true_slope = 7
true_intercept = 30
marks = true_slope * study_hours + true_intercept + noise_factor

# %%
plt.scatter(x = study_hours, y = marks)
plt.show()

# %%
marks
# Out:
# array([ 56.65304366,  95.0549647 ,  81.69837981,  61.96824932,
#         39.82294539,  42.70517928,  41.45532308,  88.04097911,
#         68.03558281,  77.05629523,  36.01792519,  99.5374452 ,
#         85.62218384,  47.43007491,  43.21313545,  47.68154064,
#         47.78669154,  65.09463948,  58.27561054,  43.06846507,
#         74.31030402,  41.06984661,  50.47569268,  54.47239336,
#         54.84804518,  82.85909068,  42.26359217,  61.98502434,
#         70.66259126,  35.27178317,  81.95906914,  42.80957772,
#         35.84136346,  96.04975803,  88.00038624,  86.45524499,
    "marks": marks
})
student_df.head(5)
# Out:
#    study_Hours      marks
# 0     3.745401  56.653044
# 1     9.507143  95.054965
# 2     7.319939  81.698380
# 3     5.986585  61.968249
# 4     1.560186  39.822945

# %% [markdown]
# visuliza the data (scatter plot)

# %%
plt.scatter(x = study_hours, y = marks, c = 'green')
plt.xlabel("Study Hours")
plt.ylabel("Marks of student")
plt.title("Study hours vs Marks of the student")
plt.show()

# %% [markdown]
# ### Split the data into features and target

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\desktop\machine learning\mlenv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\lenovo\desktop\machine learning\mlenv\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\desktop\machine learning\mlenv\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lenovo\desktop\machine learning\mlenv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo\desktop\machine learning\mlenv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\LENOVO\Desktop\Machine learning\mlenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\LENOVO\Desktop\Machine learning\mlenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\LENOVO\Desktop\Machine learning\mlenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\LENOVO\Desktop\Machine learning\mlenv\Lib\site-packages)

# %%
x = student_df[["study_Hours"]].values
y = student_df["marks"].values

# %%
y
# Out:
# array([ 56.65304366,  95.0549647 ,  81.69837981,  61.96824932,
#         39.82294539,  42.70517928,  41.45532308,  88.04097911,
#         68.03558281,  77.05629523,  36.01792519,  99.5374452 ,
#         85.62218384,  47.43007491,  43.21313545,  47.68154064,
#         47.78669154,  65.09463948,  58.27561054,  43.06846507,
#         74.31030402,  41.06984661,  50.47569268,  54.47239336,
#         54.84804518,  82.85909068,  42.26359217,  61.98502434,
#         70.66259126,  35.27178317,  81.95906914,  42.80957772,
#         35.84136346,  96.04975803,  88.00038624,  86.45524499,
#         51.62411489,  49.15325854,  76.93450703,  62.31841127,
#         38.36911759,  58.81899352,  38.12131055,  97.41209331,
#         52.06975845,  71.82962263,  58.83374688,  59.39550617,
#         71.20400502,  53.89209002,  92.91824232,  81.42780899,
#         96.26318273,  90.12053626,  64.09968136,  94.87401133,
#         30.88295658,  46.08676252,  28.56878905,  60.52279518,
#         53.29114382,  47.38412464,  92.07921173,  48.81841129,
#         50.80271535,  74.52443959,  31.82727958,  87.07695795,
#         36.51795903, 100.        ,  77.8723803 ,  37.30781464,
#         32.99625603,  88.56722336,  80.73247832,  82.76274281,
#         80.58880066,  36.34439411,  56.55796336,  34.53907708,
#         99.74611237,  76.00003348,  47.20634425,  37.73185256,
#         46.89535417,  56.69825556,  86.86541038,  70.5256114 ,
#         96.92177263,  65.1189494 ,  42.48189802,  89.41110002,
#         82.02801282,  65.52072301,  79.52013045,  60.48664032,
#         66.20578951,  61.63363116,  33.16279287,  41.68831613])

# %% [markdown]
# ### split the data into training and testing (80% train and 20%)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### Creating and train the linear regression model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make the prediction on test data

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([35.09123218, 91.42179221, 83.11504019, 75.67974665, 48.3203359 ,
#        60.61096045, 50.58127715, 89.27203511, 32.17912866, 56.16476816,
#        60.05478469, 71.95422632, 86.04359715, 95.08502028, 38.88847878,
#        41.35676105, 83.04900889, 35.80183155, 87.19432116, 42.33971843])

# %% [markdown]
# ### Evaluate the model

# %%
compare = pd.DataFrame({
    "Actual": y_test,
    "Predicted": y_test,
    "Predicted": y_pred
})

# %%
compare
# Out:
#        Actual  Predicted
# 0   37.731853  35.091232
# 1   90.120536  91.421792
# 2   77.872380  83.115040
# 3   71.829623  75.679747
# 4   52.069758  48.320336
# 5   62.318411  60.610960
# 6   50.475693  50.581277
# 7   99.746112  89.272035
# 8   36.017925  32.179129
# 9   56.653044  56.164768
# 10  58.275611  60.054785
# 11  81.959069  71.954226
# 12  88.567223  86.043597
# 13  96.049758  95.085020
# 14  42.481898  38.888479
# 15  39.822945  41.356761
# 16  80.588801  83.049009
# 17  36.344394  35.801832
# 18  85.622184  87.194321
# 19  42.809578  42.339718

# %%
compare.round(3)
# Out:
#     Actual  Predicted
# 0   37.732     35.091
# 1   90.121     91.422
# 2   77.872     83.115
# 3   71.830     75.680
# 4   52.070     48.320
# 5   62.318     60.611
# 6   50.476     50.581
# 7   99.746     89.272
# 8   36.018     32.179
# 9   56.653     56.165
# 10  58.276     60.055
# 11  81.959     71.954
# 12  88.567     86.044
# 13  96.050     95.085
# 14  42.482     38.888
# 15  39.823     41.357
# 16  80.589     83.049
# 17  36.344     35.802
# 18  85.622     87.194
# 19  42.810     42.340

# %% [markdown]
# ### Display the result

# %%
print(f"Slope (model learned): {model.coef_[0]}")
print(f"Intercept (model learned): {model.intercept_}")

print("Equation of our trained model: ")
print(f"marks = study_hours * {model.coef_[0]} + {model.intercept_}")
# Out:
# Slope (model learned): 6.776453834249748
# Intercept (model learned): 30.784229911883948
# Equation of our trained model:
# marks = study_hours * 6.776453834249748 + 30.784229911883948

# %% [markdown]
# ### Visualiza the regression line

# %%
plt.scatter(x = x_test, y = y_test, c = 'green', label = "Actual")
plt.scatter(x = x_test, y = y_pred, c = 'red', label = "prediction")
plt.xlabel("Study Hours")
plt.ylabel("Marks of student")
plt.title("Study hours vs Marks of the student")
plt.show()

# %% [markdown]
# ### Make a prediction for noew students

# %%
new_study_hours = [[5.0]]
marks_predicted = model.predict(new_study_hours)

# %%
print(f"The predicted marks of student who studies {new_study_hours[0][0]} is {marks_predicted[0].round(2)}")
# Out:
# The predicted marks of student who studies 5.0 is 64.67

# %%
new_study_hours = [[10.0]]
marks_predicted = model.predict(new_study_hours)

# %%
print(f"The predicted marks of student who studies {new_study_hours[0][0]} is {marks_predicted[0].round(2)}")
# Out:
# The predicted marks of student who studies 10.0 is 98.55
