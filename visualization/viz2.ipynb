# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Box plot

# %%
data = np.random.normal(50, 3, 100)
data
# Out:
# array([48.49958547, 50.3619524 , 51.66014094, 45.73410739, 51.48654789,
#        47.80354251, 50.87345248, 51.34536168, 53.47089003, 46.89866296,
#        51.04559351, 52.01863863, 47.34167048, 50.76032446, 51.51407724,
#        49.86092464, 51.72511208, 45.99176251, 49.75894713, 49.33644734,
#        52.25907754, 43.26316883, 51.31622868, 51.60457254, 48.30276355,
#        50.88887744, 49.24425173, 49.13767194, 54.01896803, 51.87375723,
#        54.35224548, 48.27354774, 52.27260905, 54.81598548, 47.63456122,
#        48.46051388, 49.6087767 , 51.03659026, 48.11319797, 49.74065985,
#        49.95505142, 53.40141413, 57.45300682, 53.79568542, 49.6555716 ,
#        47.47160221, 51.12652246, 47.91711454, 48.780162  , 52.04239231,
#        50.58547464, 48.57522866, 50.48513932, 47.15510074, 49.41042543,
#        49.62003649, 44.23435827, 45.70748731, 46.89950377, 48.04822482,
#        46.49377966, 52.26549229, 52.42646344, 46.13539885, 54.05725711,
# ...

# %%
plt.boxplot(data)
plt.show()

# %%
iris = pd.read_csv(r"C:\Users\LENOVO\Desktop\Machine learning\IRIS (2).csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Getting some basic info about data

# %% [markdown]
# ### Distribution plot

# %%
# Histrogram
sns.histplot(data =  iris, x = 'petal_width', bins = 20)
plt.title("Distrubution of Petal Width")
plt.show()

# %%
# Histrogram
sns.histplot(data =  iris, x = 'petal_width', hue = 'species', bins = 20)
plt.title("Distrubution of Petal Width")
plt.show()

# %%
# Barplot

sns.barplot(data = iris, x = 'species', y = 'sepal_length', palette = 'Set2')
plt.title("BAr graph distribution of sepal_length based on species")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18180\2593558828.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = iris, x = 'species', y = 'sepal_length', palette = 'Set2')
# Text(0.5, 1.0, 'BAr graph distribution of sepal_length based on species')

# %%
#heatmap
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
corr_df = iris.drop(columns =['species'])

# %%
corr_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
correlation = corr_df.corr()

# %%
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(data = correlation, annot = True)
plt.show()
